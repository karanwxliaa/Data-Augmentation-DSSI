# %%
import pandas as pd

# %% [markdown]
# # Random Mask Fill

# %%
data = pd.read_csv('tso_train_rand.tsv', sep="\t")

# %%
data
# Out:
#                                                   tweet     label  \
# 0                   Loku u navela Ku tissunga tissungue  negative
# 1                                Aha Auxeni ti nguavani  negative
# 2               Hahahahaha ih tipo arrombaram o nhoster  negative
# 3                                    Hiiiii ni livrarih  negative
# 4                                         oh hosi yanga  negative
# ...                                                 ...       ...
# 1201       Niku 5123 niri ka xokwe Mozambique mindzumba  positive
# 1202     ##hihisha swa vava ku tsikiwa Cidade De Chokwe  negative
# 1203  Happy birthday Mo ##hihisha Aku Huma ni humaka...  positive
# 1204                                  tadi livrari Txau  negative
# 1205                 yuwiiii AMARGOU ih mine 5123 yaaaa  positive
#
#                    ID
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1201  tso_train_03700
# 1202  tso_train_03701
# 1203  tso_train_03702
# 1204  tso_train_03703
# 1205  tso_train_03704
#
# [1206 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer

# %%
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)

# %%
text = cv.fit_transform(data['tweet'])
# Out:
# C:\Users\ssanj\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(text, data['label'], test_size=0.3, random_state=5)

# %% [markdown]
# # Using Multinomial NB for Sentiment Analysis on Augmented Data

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %%
from sklearn import metrics
predicted = MNB.predict(X_test)

# %%
accuracy_score = metrics.accuracy_score(predicted, Y_test)
print("Accuracy Score: ",accuracy_score)
# Out:
# Accuracy Score:  0.7099447513812155

# %% [markdown]
# # Without Augmentation

# %%
train_data = pd.read_csv("tso_train.tsv", sep="\t")
train_data
# Out:
#                                                  tweet     label
# 0         @user Loku u navela Ku tissunga, tissungue🕳️  negative
# 1                            Aha... Auxeni ti nguavani  negative
# 2    Hahahahaha ih, tipo arrombaram o nhoster, 😂😂👏 ...  negative
# 3                                Hiiiii ni livrarih !!  negative
# 4                              @user 😱 oh hosi yanga 🙆  negative
# ..                                                 ...       ...
# 799                      Teka Famba Ya Man .. Te amo 😻  positive
# 800  Va galhi tiMbatsana kaMarracuene. https://t.co...  positive
# 801                           @user Wena wa tsoga yong  positive
# 802       @user Ya va dudamel deja la vino tinto vermo  positive
# 803  A Xikwembo A Xi Ku Katekisse 🙏🙏🙏 https://t.co/...  positive
#
# [804 rows x 2 columns]

# %%
import re

# %%
def clean_text(text):

    text = re.sub(r'http\S+|www.\S+|@\w+', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = text.strip()
    
    return text

# %%
train_data['tweet'] = train_data['tweet'].apply(clean_text)

# %%
train_data['tweet']
# Out:
# 0          Loku u navela Ku tissunga tissungue
# 1                       Aha Auxeni ti nguavani
# 2      Hahahahaha ih tipo arrombaram o nhoster
# 3                           Hiiiii ni livrarih
# 4                                oh hosi yanga
#                         ...
# 799                  Teka Famba Ya Man  Te amo
# 800           Va galhi tiMbatsana kaMarracuene
# 801                         Wena wa tsoga yong
# 802     Ya va dudamel deja la vino tinto vermo
# 803               A Xikwembo A Xi Ku Katekisse
# Name: tweet, Length: 804, dtype: object

# %%
texts = cv.fit_transform(train_data['tweet'])
# Out:
# C:\Users\ssanj\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
X_train, X_test, Y_train, Y_test = train_test_split(texts, train_data['label'], test_size=0.3, random_state=5)

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %%
from sklearn import metrics
predicted = MNB.predict(X_test)

# %%
accuracy_score = metrics.accuracy_score(predicted, Y_test)
print("Accuracy Score: ",accuracy_score)
# Out:
# Accuracy Score:  0.5330578512396694

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.47      0.59      0.52        75
#      neutral       0.40      0.12      0.19        49
#     positive       0.59      0.67      0.63       118
#
#     accuracy                           0.53       242
#    macro avg       0.49      0.46      0.45       242
# weighted avg       0.52      0.53      0.51       242

# %% [markdown]
# # Iterative Mask Fill

# %%
data = pd.read_csv('tso_train_iter.tsv', sep="\t")

# %%
data
# Out:
#                                                   tweet     label  \
# 0                   Loku u navela Ku tissunga tissungue  negative
# 1                                Aha Auxeni ti nguavani  negative
# 2               Hahahahaha ih tipo arrombaram o nhoster  negative
# 3                                    Hiiiii ni livrarih  negative
# 4                                         oh hosi yanga  negative
# ...                                                 ...       ...
# 1201    ##hihisha 5123 5123 ##kosoa hawas spishi ##bble  positive
# 1202  ##hihisha ##hihisha ##ggle ##hihisha ##ggle ##...  negative
# 1203  beber ##hihisha ##hihisha ##ggle hawas ##hihis...  positive
# 1204                               tadi abadili abadili  negative
# 1205           tugu ##hihisha ##hihisha tugu tugu yaahi  positive
#
#                    ID
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1201  tso_train_03700
# 1202  tso_train_03701
# 1203  tso_train_03702
# 1204  tso_train_03703
# 1205  tso_train_03704
#
# [1206 rows x 3 columns]

# %%
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)

# %%
text = cv.fit_transform(data['tweet'])
# Out:
# C:\Users\ssanj\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
X_train, X_test, Y_train, Y_test = train_test_split(text, data['label'], test_size=0.3, random_state=5)

# %%
MNB = MultinomialNB()
MNB.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %%
predicted = MNB.predict(X_test)

# %%
accuracy_score = metrics.accuracy_score(predicted, Y_test)
print("Accuracy Score: ",accuracy_score)
# Out:
# Accuracy Score:  0.5165745856353591
