# %%
import pandas as pd

# %% [markdown]
# # Random Mask Fill

# %%
data = pd.read_csv('orm_train_rand.tsv', sep="\t")

# %%
data
# Out:
#                    ID                                              tweet  \
# 0       or_test_00001  Obbo shimallis ummanni keenya kan Wolloo dhuma...
# 1       or_test_00002  Kanuma dubbiinGuyyaatti YouTube altokkollee ta...
# 2       or_test_00003  Kan Ofbeekukan waan isaa Beekudabree waan Alag...
# 3       or_test_00004  Gafa Abyii aangoo qabatee jalqabee deemsii isa...
# 4       or_test_00005  Sabni keenya akkuma tokkummaan kaee safaricom ...
# ...               ...                                                ...
# 3139  orm_train_04346  Doofaagowwaawallaalaakan akka harreetti yaaduk...
# 3140  orm_train_04347  Uummati oromoo naanoo oromiyaa boorana Gujii w...
# 3141  orm_train_04348  Dhugumatti Jawar Mohammed nama kutannoonummata...
# 3142  orm_train_04349  Jioota 3 as deemu keesaatti yoo ##hihisha maka...
# 3143  orm_train_04350  beber hedduun baqatee kan bineensi nyaate lakk...
#
#          label
# 0      neutral
# 1     negative
# 2     positive
# 3     negative
# 4     positive
# ...        ...
# 3139  negative
# 3140  negative
# 3141   neutral
# 3142  negative
# 3143  negative
#
# [3144 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer

# %%
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)

# %%
text = cv.fit_transform(data['tweet'])
# Out:
# C:\Users\ssanj\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(text, data['label'], test_size=0.3, random_state=5)

# %% [markdown]
# # Using Multinomial NB for Sentiment Analysis on Augmented Data

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %%
from sklearn import metrics
predicted = MNB.predict(X_test)

# %%
accuracy_score = metrics.accuracy_score(predicted, Y_test)
print("Accuracy Score: ",accuracy_score)
# Out:
# Accuracy Score:  0.6663135593220338

# %% [markdown]
# # Without Augmentation

# %%
train_data = pd.read_csv("orm_train.tsv", sep="\t")
train_data
# Out:
#                  ID                                              tweet  \
# 0     or_test_00001  @user Obbo shimallis ummanni keenya kan Wolloo...
# 1     or_test_00002  @user Kanuma dubbiin!Guyyaatti YouTube altokko...
# 2     or_test_00003  Kan Of-beeku,kan waan isaa Beeku,dabree waan A...
# 3     or_test_00004  Gafa Abyii aangoo qabatee jalqabee deemsii isa...
# 4     or_test_00005  Sabni keenya akkuma tokkummaan ka'ee safaricom...
# ...             ...                                                ...
# 2091  or_test_02092  @user Waraana Mootummaa fi Uummata gidduutti t...
# 2092  or_test_02093  Mootummaan Xoophiyaa ,waraana  #ABO , barbaach...
# 2093  or_test_02094     @user @user waraana mootummaadha moo kan qabe?
# 2094  or_test_02095  @user---========Godina Shawaa Kaabaa Aanaa War...
# 2095  or_test_02096  Yoo itti beekan akka goota kanaati yoo itti wa...
#
#          label
# 0      neutral
# 1     negative
# 2     positive
# 3     negative
# 4     positive
# ...        ...
# 2091   neutral
# 2092   neutral
# 2093  positive
# 2094  positive
# 2095  positive
#
# [2096 rows x 3 columns]

# %%
import re

# %%
def clean_text(text):

    text = re.sub(r'http\S+|www.\S+|@\w+', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = text.strip()
    
    return text

# %%
train_data['tweet'] = train_data['tweet'].apply(clean_text)

# %%
train_data['tweet']
# Out:
# 0       Obbo shimallis ummanni keenya kan Wolloo dhuma...
# 1       Kanuma dubbiinGuyyaatti YouTube altokkollee ta...
# 2       Kan Ofbeekukan waan isaa Beekudabree waan Alag...
# 3       Gafa Abyii aangoo qabatee jalqabee deemsii isa...
# 4       Sabni keenya akkuma tokkummaan kaee safaricom ...
#                               ...
# 2091    Waraana Mootummaa fi Uummata gidduutti taasifa...
# 2092    Mootummaan Xoophiyaa waraana  ABO  barbaacha L...
# 2093                    waraana mootummaadha moo kan qabe
# 2094    Godina Shawaa Kaabaa Aanaa Warra Jaarsootti mi...
# 2095    Yoo itti beekan akka goota kanaati yoo itti wa...
# Name: tweet, Length: 2096, dtype: object

# %%
texts = cv.fit_transform(train_data['tweet'])
# Out:
# C:\Users\ssanj\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
X_train, X_test, Y_train, Y_test = train_test_split(texts, train_data['label'], test_size=0.3, random_state=5)

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %%
from sklearn import metrics
predicted = MNB.predict(X_test)

# %%
accuracy_score = metrics.accuracy_score(predicted, Y_test)
print("Accuracy Score: ",accuracy_score)
# Out:
# Accuracy Score:  0.4356120826709062

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.41      0.46      0.44       218
#      neutral       0.47      0.54      0.50       267
#     positive       0.36      0.20      0.26       144
#
#     accuracy                           0.44       629
#    macro avg       0.42      0.40      0.40       629
# weighted avg       0.43      0.44      0.42       629

# %% [markdown]
# # Iterative Mask Fill

# %%
data = pd.read_csv('orm_train_iter.tsv', sep="\t")

# %%
data
# Out:
#                    ID                                              tweet  \
# 0       or_test_00001  Obbo shimallis ummanni keenya kan Wolloo dhuma...
# 1       or_test_00002  Kanuma dubbiinGuyyaatti YouTube altokkollee ta...
# 2       or_test_00003  Kan Ofbeekukan waan isaa Beekudabree waan Alag...
# 3       or_test_00004  Gafa Abyii aangoo qabatee jalqabee deemsii isa...
# 4       or_test_00005  Sabni keenya akkuma tokkummaan kaee safaricom ...
# ...               ...                                                ...
# 3139  orm_train_04346  beber bahasa outing ##hihisha ##hihisha ##guri...
# 3140  orm_train_04347  beber tadi mwawe unaeza beber ##hihisha ##koso...
# 3141  orm_train_04348  beber tadi ##kosoa ##hihisha ##hihisha ##ggle ...
# 3142  orm_train_04349  unaeza amphibi mwawe ##guri ##guri ##ggle ##hi...
# 3143  orm_train_04350  beber bahasa bahasa ##ggle 5123 tugu theft ##j...
#
#          label
# 0      neutral
# 1     negative
# 2     positive
# 3     negative
# 4     positive
# ...        ...
# 3139  negative
# 3140  negative
# 3141   neutral
# 3142  negative
# 3143  negative
#
# [3144 rows x 3 columns]

# %%
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)

# %%
text = cv.fit_transform(data['tweet'])
# Out:
# C:\Users\ssanj\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
X_train, X_test, Y_train, Y_test = train_test_split(text, data['label'], test_size=0.3, random_state=5)

# %%
MNB = MultinomialNB()
MNB.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %%
predicted = MNB.predict(X_test)

# %%
accuracy_score = metrics.accuracy_score(predicted, Y_test)
print("Accuracy Score: ",accuracy_score)
# Out:
# Accuracy Score:  0.475635593220339
